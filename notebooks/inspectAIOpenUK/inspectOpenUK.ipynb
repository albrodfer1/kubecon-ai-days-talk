# %% [markdown]
# ## Inspect

# %%
## retrieve secrets
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["GITHUB_TOKEN"] = userdata.get('GITHUB_TOKEN')
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %% [markdown]
# ### Start a poetry environment

# %%
# TODO: download the repo folder
# !poetry install --no-root
# Out:
# Retrieving Poetry metadata
#
# # Welcome to Poetry!
#
# This will download and install the latest version of Poetry,
# a dependency and package manager for Python.
#
# It will add the `poetry` command to Poetry's bin directory, located at:
#
# /root/.local/bin
#
# You can uninstall at any time by executing this script with the --uninstall option,
# and these changes will be reverted.
#
# Installing Poetry (2.1.1)
# Installing Poetry (2.1.1): Creating environment
# Installing Poetry (2.1.1): Installing Poetry
# Installing Poetry (2.1.1): Creating script
# Installing Poetry (2.1.1): Done
#
# Poetry (2.1.1) is installed now. Great!
#
# To get started you need Poetry's bin directory (/root/.local/bin) in your `PATH`
# environment variable.
#
# Add `export PATH="/root/.local/bin:$PATH"` to your shell configuration file.
#
# Alternatively, you can call Poetry explicitly with `/root/.local/bin/poetry`.
#
# You can test that everything is set up by executing:
#
# `poetry --version`
#
# ...

# %%
# !which inspect
# Out:
# /usr/local/bin/inspect

# %%
# perform analysis of gpt-4o
# !inspect eval inspect_evals/agentharm --model openai/gpt-4o-2024-08-06
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 6 files: 100% 6/6 [00:00<00:00, 7602.97it/s]
# [>1u[?2026$p[?2048$p
#   Tasks   Running Samples   Console
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                 HTTP rate limits: 0
#   Tasks   Running Samples   Console
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                 HTTP rate limits: 0
#   Tasks   Running Samples   Console
# ...

# %%
# !cp logs/* ./inspectOpenUK/logs
# %cd inspectOpenUK
# !git add .
# !git config --global user.email "alberto.rodriguez@control-plane.io"
# !git config --global user.name "Alberto Rodriguez"
# !git commit -m "update dependencies"
# !git push  https://albrodfer1:${GITHUB_TOKEN}@github.com/albrodfer1/inspectOpenUK.git
# %cd ..
# Out:
# /content/inspectOpenUK
# [main 310dcf6] update dependencies
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 logs/2025-03-11T19-09-48+00-00_agentharm_MNxgVUL8qwXveLGaN4DTBw.eval
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 103.93 KiB | 20.79 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/albrodfer1/inspectOpenUK.git
#    74c8cc1..310dcf6  main -> main
# /content
